# %% [markdown]
# <big><i>
# All the Notebooks on **Python Internship** lecture series by **[Abdul Aziz MD](https://www.linkedin.com/in/abdul-aziz-md/)**
# </i></big>

# %% [markdown]
# ## Lists in Python
#
# A list is an in-built Python data structure that can be changed. It is an ordered and changeable collection of elements. By ordered sequence, it is meant that every element of the list can be called individually by its index number.
#
# - Some of the important points about the list are:
# - The list can be created by placing all elements inside a square bracket `[]`.
# - All elements inside the list must be separated by a comma `“,”`.
# - It can have any number of elements and the elements need not be of the same type. So, we can also say that it is a collection of heterogeneous data types.
# - Lists index always starts from `0`, so if the length of a string is `“n”`, then the last element will have an index of `n-1`.
# - Lists are mutable therefore they can be modified after creation.
# - An Empty List is denoted as `L[ ]`.
#
# ![image.png](attachment:image.png)

# %%
# a simple list   
list1 = [1, 'A', "Python", "Program", 15.9]      
list2 = ["Ami", "Maya", "Hari", "Lia"]   
list3 = ["C", "C++",["Java","pyhon","C#"],[1,2,3,4],True,False,[1+3j,-9j,4-8j]] #lists of list or Nested lists
  
# printing the list  
print(list1)  
print(list2)  
print(list3)
  
# printing the type of list  
print(type(list1))  
print(type(list2))
print(type(list3))
# Out:
# [1, 'A', 'Python', 'Program', 15.9]
# ['Ami', 'Maya', 'Hari', 'Lia']
# ['C', 'C++', ['Java', 'pyhon', 'C#'], [1, 2, 3, 4], True, False, [(1+3j), (-0-9j), (4-8j)]]
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
Str = "Hello World"
list_str = list(Str)
print(list_str)
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'W', 'o', 'r', 'l', 'd']

# %%
"".join(list_str)
# Out:
# 'Hello World'

# %% [markdown]
# ### Finding Length of List

# %%
print("lengh of list1:::", len(list1))
print("lengh of list2:::", len(list2))
print("lengh of list3:::", len(list3))
# Out:
# lengh of list1::: 5
# lengh of list2::: 4
# lengh of list3::: 7

# %% [markdown]
# ### Indexing

# %%
colors = ['red', 'green', 'blue', 'yellow', 'white', 'black']
print(colors)
# Out:
# ['red', 'green', 'blue', 'yellow', 'white', 'black']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
colors[0]
# Out:
# 'red'

# %%
colors[2]
# Out:
# 'blue'

# %%
colors[5]
# Out:
# 'black'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
colors[-2]
# Out:
# 'white'

# %%
colors[-4]
# Out:
# 'blue'

# %% [markdown]
# ### Assignment

# %%
colors[0] ="Pink"

# %%
colors
# Out:
# ['Pink', 'green', 'blue', 'yellow', 'white', 'black']

# %%
colors[6]="red"
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 colors[6]="red"
#
# IndexError: list assignment index out of range

# %%
colors[3]="blue"

# %%
colors
# Out:
# ['Pink', 'green', 'blue', 'blue', 'white', 'black']

# %% [markdown]
# ### Deletion
# - We can also easily delete any element from the list by using indexing and `del` statement.

# %%
del colors[0]

# %%
colors
# Out:
# ['green', 'blue', 'blue', 'white', 'black']

# %%
colors[0]
# Out:
# 'green'

# %% [markdown]
# ### Accessing List Elemets

# %%
list3 = ["C", "C++",["Java","pyhon","C#","C","Ruby","Go","JavaScript","HTML", "CSS"]] #lists of list
print(list3)
# Out:
# ['C', 'C++', ['Java', 'pyhon', 'C#', 'C', 'Ruby', 'Go', 'JavaScript', 'HTML', 'CSS']]

# %%
list3[2]
# Out:
# ['Java', 'pyhon', 'C#', 'C', 'Ruby', 'Go', 'JavaScript', 'HTML', 'CSS']

# %%
list3[2][0]
# Out:
# 'Java'

# %%
list3[2][-1]
# Out:
# 'CSS'

# %%
list3[2][1]='Java'

# %%
list3
# Out:
# ['C',
#  'C++',
#  ['Java', 'Java', 'C#', 'C', 'Ruby', 'Go', 'JavaScript', 'HTML', 'CSS']]

# %%
del list3[2][0]

# %%
list3
# Out:
# ['C', 'C++', ['Java', 'C#', 'C', 'Ruby', 'Go', 'JavaScript', 'HTML', 'CSS']]

# %% [markdown]
# ## Slicing a List
#
# If `L` is a list, the expression `L [ start : stop : step ]` returns the portion of the list from index `star`t to index `stop`, at a step size `step`.
#
# ![image.png](attachment:image.png)

# %%
nums = [10, 20, 30, 40, 50, 60, 70, 80, 90]
some_nums = nums[2:7]
some_nums
# Out:
# [30, 40, 50, 60, 70]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
nums = [10, 20, 30, 40, 50, 60, 70, 80, 90]
some_nums = nums[5:7]
some_nums
# Out:
# [60, 70]

# %%
nums = [10, 20, 30, 40, 50, 60, 70, 80, 90]
some_nums = nums[1:7:3]
some_nums
# Out:
# [20, 50]

# %%
nums = [10, 20, 30, 40, 50, 60, 70, 80, 90]
some_nums = nums[1:7:2]
some_nums
# Out:
# [20, 40, 60]

# %%
nums = [10, 20, 30, 40, 50, 60, 70, 80, 90]
some_nums = nums[-1:-5]
some_nums
# Out:
# []

# %%
nums = [10, 20, 30, 40, 50, 60, 70, 80, 90]
some_nums = nums[-5:-1]
some_nums
# Out:
# [50, 60, 70, 80]

# %%
nums = [10, 20, 30, 40, 50, 60, 70, 80, 90]
some_nums = nums[-5:-1:2]
some_nums
# Out:
# [50, 70]

# %%
nums = [10, 20, 30, 40, 50, 60, 70, 80, 90]
some_nums = nums[::-1] # Reversing a list
some_nums
# Out:
# [90, 80, 70, 60, 50, 40, 30, 20, 10]

# %% [markdown]
# ### List concatenation and repeation
#
# Use `+` operator to create a new list that is a concatenation of two lists and use `*` operator to repeat a list. See the following statements.

# %%
color_list1 = ["White", "Yellow"]
color_list2 = ["Red", "Blue"]
color_list3 = ["Green", "Black"]
color_list = color_list1 + color_list2 + color_list3
print(color_list)
# Out:
# ['White', 'Yellow', 'Red', 'Blue', 'Green', 'Black']

# %%
number = [1,2,3]
print(number[0]*4)
print(number*4)
# Out:
# 4
# [1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3]

# %% [markdown]
# <center><h1>Happy Learning </h1><center>
